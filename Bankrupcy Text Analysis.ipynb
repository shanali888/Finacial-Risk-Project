# %% [markdown]
# # Text Analysis Workbook for Bankrupcy Project

# %% [markdown]
# #### Notes:
# - Explore/select features

# %% [markdown]
# ### Initialize Libaries, Data, & Structures

# %%
# load libaries
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from statsmodels.api import OLS, add_constant
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_roc_curve
import statsmodels.api as sm 
import pandas as pd
import numpy as np

# %% [markdown]
# ### Full File Load & Merge

# %%
# load linking data
links = pd.read_csv('firm-links.csv')
links = links[['LPERMNO','cik','datadate']]
links['date_month'] = pd.to_datetime(links['datadate']).dt.to_period('M')
links = links.rename(columns={'cik':'CIK','LPERMNO':'PERMNO'})
links = links[['PERMNO','CIK','date_month']]

# load firm data
#data = pd.read_csv('data-clean.csv', low_memory=False)
data = pd.read_csv('data-exclude.csv', low_memory=False)
data['PRC'] = np.where(data['PRC'] >= 15, 15, data['PRC'])
data['year'] = pd.to_datetime(data['date_month']).dt.to_period('Y')
data['date_month'] = pd.to_datetime(data['date_month']).dt.to_period('M')

# define constants & structures
y_col = 'financialDistress_12_periods'

# %%
# load text data
text = pd.read_csv('text-data.csv', encoding='latin-1')
text['date_month'] = pd.to_datetime(text['FDATE'], format='%Y%m%d').dt.to_period('M')
target_forms = ['10-K','10-Q']#,'8-K']
text = text[text.Form.isin(target_forms)].reset_index(drop=True)
text.Form.value_counts()
# Out:
# 10-Q    587983
# 10-K    191743
# Name: Form, dtype: int64

# %% [markdown]
# ### Merge Datasets & Save Text + Original Data

# %%
print('Size pre-cik merge:', data[data['date_month'].between('1994-01','2018-12')].shape)
print('Data date range:',data['date_month'].min(), data['date_month'].max())
print('Text date range:',text['date_month'].min(), text['date_month'].max())
print('Link date range:',links['date_month'].min(), links['date_month'].max(),'\n')

# merge linking information (PERMNO to CIK)
d = data[data['date_month'].between('1994-01','2018-12')]
merged = d.merge(links, on=['PERMNO','date_month'], how='left')
print('Size post-cik merge:', merged.shape)
print('Cik nan count:', merged.CIK.isna().sum())
print('Date range:',merged['date_month'].min(), merged['date_month'].max(),'\n')

# merge text data (on CIK, date_month)
merged = merged.merge(text, on=['CIK','date_month'], how='left')
print('Size post-text merge:', merged.shape)
print('Cik nan count:', merged.CIK.isna().sum())
print('Date range:', merged['date_month'].min(), merged['date_month'].max(),'\n')

# reduce firm-months w/ multipule reportings
m = merged.groupby(['date_month','PERMNO']).mean()
m['doc_count'] = merged.groupby(['date_month','PERMNO']).count()['RET']
m['doc_count'] = np.where(m['FinTerms_Litigious'].isna(),0,m['doc_count'])
m = m.reset_index().drop(columns=['CIK','FDATE'])
print('Final size:', m.shape)
vc = m['financialDistress_12_periods'].value_counts(dropna=False)
print('Final distress count:', vc[1], '/', (vc[0]+vc[1]))
print('Final date range:', m['date_month'].min(), m['date_month'].max())
# Out:
# Size pre-cik merge: (823090, 17)
# Data date range: 1972-02 2018-11
# Text date range: 1994-01 2019-09
# Link date range: 1990-01 2020-12
#
# Size post-cik merge: (823090, 18)
# Cik nan count: 527803
# Date range: 1994-01 2018-11
#
# Size post-text merge: (823709, 47)
# Cik nan count: 527803
# Date range: 1994-01 2018-11
#
# Final size: (823090, 43)
# Final distress count: 25906 / 823090
# Final date range: 1994-01 2018-11

# %%
# replace nans with retroactive 
cols = ['Gunning_Fog_Index','ARI','SMOG_Index','ParagraphCount','CharCount','WordCount',
        'ComplexWordCount','SentenceCount','averageWordsPerParagraph','CharCountTokens',
        'FinTerms_Negative','FinTerms_ModalWeak_count','FinTerms_ModalStrong_count', 
        'FinTerms_Positive','HarvardIV_Negative','FinTerms_Litigious_count','FinTerms_Uncertainty_count',
        'FinTerms_ModalWeak','FinTerms_Litigious','LM_Master_Dictionary','FinTerms_Uncertainty', 
        'LM_Master_Dictionary_count','HarvardIV_Negative_count','FinTerms_Negative_count',
        'FinTerms_ModalStrong','FinTerms_Positive_count']

m2 = m.sort_values(['PERMNO','date_month']).reset_index(drop=True)
mask = (m2.PERMNO == m2.PERMNO.shift(1)) & (m2.WordCount.isna())
for col in cols[:]: m2[col] = np.where(mask, m2[col].shift(1), m2[col])
mask = (m2.PERMNO == m2.PERMNO.shift(1)) & (m2.WordCount.isna()) 
for col in cols[:]: m2[col] = np.where(mask, m2[col].shift(1), m2[col])
m2 = m2.replace(np.nan,0) # interaction variable btw presence & magnitude of report

# %%
#m2.to_csv('data-exclude-text.csv',index=False)
#m2.to_csv('data-clean-text.csv',index=False)

# %% [markdown]
# ### Quick File Load

# %%
# load firm data & define constants & structures
#merged = pd.read_csv('data-clean-text.csv', low_memory=False)
merged = pd.read_csv('data-exclude-text.csv', low_memory=False)
merged['year'] = pd.to_datetime(merged['date_month']).dt.to_period('Y')
merged['date_month'] = pd.to_datetime(merged['date_month']).dt.to_period('M')
y_col = 'financialDistress_12_periods'
cols = list(merged.columns[16:-1])

# %% [markdown]
# ### Feature Selection

# %%
# correlation analysis
cols = list(merged.columns[16:-1])
X = merged[cols]
corr_mat = X.corr()
corr_mat[(abs(corr_mat) > 0.75) & (abs(corr_mat) < 1.0)]
# ARI vs Gunning_Fog_Index
# count, sentiment, readibility predictors
# Out:
#                             Gunning_Fog_Index       ARI  SMOG_Index  \
# Gunning_Fog_Index                         NaN  0.997840    0.997044
# ARI                                  0.997840       NaN    0.993949
# SMOG_Index                           0.997044  0.993949         NaN
# ParagraphCount                            NaN       NaN         NaN
# CharCount                                 NaN       NaN         NaN
# WordCount                                 NaN       NaN         NaN
# ComplexWordCount                          NaN       NaN         NaN
# SentenceCount                             NaN       NaN         NaN
# averageWordsPerParagraph                  NaN       NaN         NaN
# CharCountTokens                           NaN       NaN         NaN
# FinTerms_Negative                    0.874081  0.864601    0.878173
# FinTerms_ModalWeak_count                  NaN       NaN         NaN
# FinTerms_ModalStrong_count                NaN       NaN         NaN
# FinTerms_Positive                    0.923689  0.920177    0.931539
# HarvardIV_Negative                   0.959924  0.957874    0.967902
# FinTerms_Litigious_count                  NaN       NaN         NaN
# FinTerms_Uncertainty_count                NaN       NaN         NaN
# FinTerms_ModalWeak                   0.769810  0.757309    0.773320
# FinTerms_Litigious                   0.785764  0.779013    0.785686
# LM_Master_Dictionary                 0.988792  0.987241    0.996062
# FinTerms_Uncertainty                 0.905852  0.894815    0.912155
# LM_Master_Dictionary_count                NaN       NaN         NaN
# HarvardIV_Negative_count                  NaN       NaN         NaN
# FinTerms_Negative_count                   NaN       NaN         NaN
# FinTerms_ModalStrong                 0.841717  0.831968    0.846880
# FinTerms_Positive_count                   NaN       NaN         NaN
#
#                             ParagraphCount  CharCount  WordCount  \
# Gunning_Fog_Index                      NaN        NaN        NaN
# ARI                                    NaN        NaN        NaN
# SMOG_Index                             NaN        NaN        NaN
# ParagraphCount                         NaN   0.949900   0.944550
# CharCount                         0.949900        NaN   0.999085
# WordCount                         0.944550   0.999085        NaN
# ComplexWordCount                  0.940432   0.996988   0.997308
# SentenceCount                     0.922887   0.970690   0.972016
# averageWordsPerParagraph               NaN        NaN        NaN
# CharCountTokens                   0.948228   0.999769   0.999264
# FinTerms_Negative                      NaN        NaN        NaN
# FinTerms_ModalWeak_count          0.809624   0.877214   0.880216
# FinTerms_ModalStrong_count        0.851320   0.911974   0.915841
# FinTerms_Positive                      NaN        NaN        NaN
# HarvardIV_Negative                     NaN        NaN        NaN
# FinTerms_Litigious_count          0.750929   0.806945   0.818612
# FinTerms_Uncertainty_count        0.854563   0.926900   0.927615
# FinTerms_ModalWeak                     NaN        NaN        NaN
# FinTerms_Litigious                     NaN        NaN        NaN
# LM_Master_Dictionary                   NaN        NaN        NaN
# FinTerms_Uncertainty                   NaN        NaN        NaN
# LM_Master_Dictionary_count        0.930822   0.993456   0.996935
# HarvardIV_Negative_count          0.904350   0.975258   0.977938
# FinTerms_Negative_count           0.868687   0.945661   0.950502
# FinTerms_ModalStrong                   NaN        NaN        NaN
# FinTerms_Positive_count           0.886456   0.955420   0.957789
#
#                             ComplexWordCount  SentenceCount  \
# Gunning_Fog_Index                        NaN            NaN
# ARI                                      NaN            NaN
# SMOG_Index                               NaN            NaN
# ParagraphCount                      0.940432       0.922887
# CharCount                           0.996988       0.970690
# WordCount                           0.997308       0.972016
# ComplexWordCount                         NaN       0.978490
# SentenceCount                       0.978490            NaN
# averageWordsPerParagraph                 NaN            NaN
# CharCountTokens                     0.997944       0.973451
# FinTerms_Negative                        NaN            NaN
# FinTerms_ModalWeak_count            0.889992       0.873193
# FinTerms_ModalStrong_count          0.918688       0.905158
# FinTerms_Positive                        NaN            NaN
# HarvardIV_Negative                       NaN            NaN
# FinTerms_Litigious_count            0.797855            NaN
# FinTerms_Uncertainty_count          0.940136       0.948016
# FinTerms_ModalWeak                       NaN            NaN
# FinTerms_Litigious                       NaN            NaN
# LM_Master_Dictionary                     NaN            NaN
# FinTerms_Uncertainty                     NaN            NaN
# LM_Master_Dictionary_count          0.995626       0.974651
# HarvardIV_Negative_count            0.981099       0.974912
# FinTerms_Negative_count             0.950553       0.918212
# FinTerms_ModalStrong                     NaN            NaN
# FinTerms_Positive_count             0.964249       0.955409
#
#                             averageWordsPerParagraph  CharCountTokens  ...  \
# Gunning_Fog_Index                                NaN              NaN  ...
# ARI                                              NaN              NaN  ...
# SMOG_Index                                       NaN              NaN  ...
# ParagraphCount                                   NaN         0.948228  ...
# CharCount                                        NaN         0.999769  ...
# WordCount                                        NaN         0.999264  ...
# ComplexWordCount                                 NaN         0.997944  ...
# SentenceCount                                    NaN         0.973451  ...
# averageWordsPerParagraph                         NaN              NaN  ...
# CharCountTokens                                  NaN              NaN  ...
# FinTerms_Negative                                NaN              NaN  ...
# FinTerms_ModalWeak_count                         NaN         0.881084  ...
# FinTerms_ModalStrong_count                       NaN         0.913941  ...
# FinTerms_Positive                                NaN              NaN  ...
# HarvardIV_Negative                               NaN              NaN  ...
# FinTerms_Litigious_count                         NaN         0.803011  ...
# FinTerms_Uncertainty_count                       NaN         0.931682  ...
# FinTerms_ModalWeak                               NaN              NaN  ...
# FinTerms_Litigious                               NaN              NaN  ...
# LM_Master_Dictionary                             NaN              NaN  ...
# FinTerms_Uncertainty                             NaN              NaN  ...
# LM_Master_Dictionary_count                       NaN         0.994490  ...
# HarvardIV_Negative_count                         NaN         0.977766  ...
# FinTerms_Negative_count                          NaN         0.947265  ...
# FinTerms_ModalStrong                             NaN              NaN  ...
# FinTerms_Positive_count                          NaN         0.958232  ...
#
#                             FinTerms_Uncertainty_count  FinTerms_ModalWeak  \
# Gunning_Fog_Index                                  NaN            0.769810
# ARI                                                NaN            0.757309
# SMOG_Index                                         NaN            0.773320
# ParagraphCount                                0.854563                 NaN
# CharCount                                     0.926900                 NaN
# WordCount                                     0.927615                 NaN
# ComplexWordCount                              0.940136                 NaN
# SentenceCount                                 0.948016                 NaN
# averageWordsPerParagraph                           NaN                 NaN
# CharCountTokens                               0.931682                 NaN
# FinTerms_Negative                                  NaN            0.776234
# FinTerms_ModalWeak_count                      0.951606                 NaN
# FinTerms_ModalStrong_count                    0.889375                 NaN
# FinTerms_Positive                                  NaN                 NaN
# HarvardIV_Negative                                 NaN            0.767451
# FinTerms_Litigious_count                           NaN                 NaN
# FinTerms_Uncertainty_count                         NaN                 NaN
# FinTerms_ModalWeak                                 NaN                 NaN
# FinTerms_Litigious                                 NaN                 NaN
# LM_Master_Dictionary                               NaN            0.762668
# FinTerms_Uncertainty                               NaN            0.890596
# LM_Master_Dictionary_count                    0.933387                 NaN
# HarvardIV_Negative_count                      0.953238                 NaN
# FinTerms_Negative_count                       0.916413                 NaN
# FinTerms_ModalStrong                               NaN                 NaN
# FinTerms_Positive_count                       0.938355                 NaN
#
#                             FinTerms_Litigious  LM_Master_Dictionary  \
# Gunning_Fog_Index                     0.785764              0.988792
# ARI                                   0.779013              0.987241
# SMOG_Index                            0.785686              0.996062
# ParagraphCount                             NaN                   NaN
# CharCount                                  NaN                   NaN
# WordCount                                  NaN                   NaN
# ComplexWordCount                           NaN                   NaN
# SentenceCount                              NaN                   NaN
# averageWordsPerParagraph                   NaN                   NaN
# CharCountTokens                            NaN                   NaN
# FinTerms_Negative                     0.817830              0.867550
# FinTerms_ModalWeak_count                   NaN                   NaN
# FinTerms_ModalStrong_count                 NaN                   NaN
# FinTerms_Positive                          NaN              0.934014
# HarvardIV_Negative                    0.763229              0.970624
# FinTerms_Litigious_count                   NaN                   NaN
# FinTerms_Uncertainty_count                 NaN                   NaN
# FinTerms_ModalWeak                         NaN              0.762668
# FinTerms_Litigious                         NaN              0.770730
# LM_Master_Dictionary                  0.770730                   NaN
# FinTerms_Uncertainty                       NaN              0.906619
# LM_Master_Dictionary_count                 NaN                   NaN
# HarvardIV_Negative_count                   NaN                   NaN
# FinTerms_Negative_count                    NaN                   NaN
# FinTerms_ModalStrong                       NaN              0.840870
# FinTerms_Positive_count                    NaN                   NaN
#
#                             FinTerms_Uncertainty  LM_Master_Dictionary_count  \
# Gunning_Fog_Index                       0.905852                         NaN
# ARI                                     0.894815                         NaN
# SMOG_Index                              0.912155                         NaN
# ParagraphCount                               NaN                    0.930822
# CharCount                                    NaN                    0.993456
# WordCount                                    NaN                    0.996935
# ComplexWordCount                             NaN                    0.995626
# SentenceCount                                NaN                    0.974651
# averageWordsPerParagraph                     NaN                         NaN
# CharCountTokens                              NaN                    0.994490
# FinTerms_Negative                       0.858176                         NaN
# FinTerms_ModalWeak_count                     NaN                    0.889747
# FinTerms_ModalStrong_count                   NaN                    0.919704
# FinTerms_Positive                       0.862456                         NaN
# HarvardIV_Negative                      0.905604                         NaN
# FinTerms_Litigious_count                     NaN                    0.828231
# FinTerms_Uncertainty_count                   NaN                    0.933387
# FinTerms_ModalWeak                      0.890596                         NaN
# FinTerms_Litigious                           NaN                         NaN
# LM_Master_Dictionary                    0.906619                         NaN
# FinTerms_Uncertainty                         NaN                         NaN
# LM_Master_Dictionary_count                   NaN                         NaN
# HarvardIV_Negative_count                     NaN                    0.982907
# FinTerms_Negative_count                      NaN                    0.958369
# FinTerms_ModalStrong                    0.826300                         NaN
# FinTerms_Positive_count                      NaN                    0.963448
#
#                             HarvardIV_Negative_count  FinTerms_Negative_count  \
# Gunning_Fog_Index                                NaN                      NaN
# ARI                                              NaN                      NaN
# SMOG_Index                                       NaN                      NaN
# ParagraphCount                              0.904350                 0.868687
# CharCount                                   0.975258                 0.945661
# WordCount                                   0.977938                 0.950502
# ComplexWordCount                            0.981099                 0.950553
# SentenceCount                               0.974912                 0.918212
# averageWordsPerParagraph                         NaN                      NaN
# CharCountTokens                             0.977766                 0.947265
# FinTerms_Negative                                NaN                      NaN
# FinTerms_ModalWeak_count                    0.901046                 0.907541
# FinTerms_ModalStrong_count                  0.905924                 0.901639
# FinTerms_Positive                                NaN                      NaN
# HarvardIV_Negative                               NaN                      NaN
# FinTerms_Litigious_count                    0.771585                 0.837958
# FinTerms_Uncertainty_count                  0.953238                 0.916413
# FinTerms_ModalWeak                               NaN                      NaN
# FinTerms_Litigious                               NaN                      NaN
# LM_Master_Dictionary                             NaN                      NaN
# FinTerms_Uncertainty                             NaN                      NaN
# LM_Master_Dictionary_count                  0.982907                 0.958369
# HarvardIV_Negative_count                         NaN                 0.966256
# FinTerms_Negative_count                     0.966256                      NaN
# FinTerms_ModalStrong                             NaN                      NaN
# FinTerms_Positive_count                     0.958111                 0.930567
#
#                             FinTerms_ModalStrong  FinTerms_Positive_count
# Gunning_Fog_Index                       0.841717                      NaN
# ARI                                     0.831968                      NaN
# SMOG_Index                              0.846880                      NaN
# ParagraphCount                               NaN                 0.886456
# CharCount                                    NaN                 0.955420
# WordCount                                    NaN                 0.957789
# ComplexWordCount                             NaN                 0.964249
# SentenceCount                                NaN                 0.955409
# averageWordsPerParagraph                     NaN                      NaN
# CharCountTokens                              NaN                 0.958232
# FinTerms_Negative                       0.797141                      NaN
# FinTerms_ModalWeak_count                     NaN                 0.901653
# FinTerms_ModalStrong_count                   NaN                 0.910646
# FinTerms_Positive                       0.816293                      NaN
# HarvardIV_Negative                      0.823318                      NaN
# FinTerms_Litigious_count                     NaN                      NaN
# FinTerms_Uncertainty_count                   NaN                 0.938355
# FinTerms_ModalWeak                           NaN                      NaN
# FinTerms_Litigious                           NaN                      NaN
# LM_Master_Dictionary                    0.840870                      NaN
# FinTerms_Uncertainty                    0.826300                      NaN
# LM_Master_Dictionary_count                   NaN                 0.963448
# HarvardIV_Negative_count                     NaN                 0.958111
# FinTerms_Negative_count                      NaN                 0.930567
# FinTerms_ModalStrong                         NaN                      NaN
# FinTerms_Positive_count                      NaN                      NaN
#
# [26 rows x 26 columns]

# %%
# For each X, calculate VIF and save in dataframe
vifcols = ['CharCountTokens','WordCount','CharCount','SMOG_Index','Gunning_Fog_Index',
           'LM_Master_Dictionary_count','ARI','LM_Master_Dictionary','ComplexWordCount',
           'HarvardIV_Negative_count','SentenceCount','FinTerms_Uncertainty_count',
           'FinTerms_Negative_count','FinTerms_Uncertainty','FinTerms_ModalWeak_count',
           'HarvardIV_Negative','FinTerms_Positive_count','ParagraphCount','FinTerms_Negative']
X2 = merged[cols].dropna()
X2 = X2.drop(columns=vifcols)
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X2.values, i) for i in range(X2.shape[1])]
vif["features"] = X2.columns

# Inspect VIF scores
vifcols = list(vif.features)
vif = vif.round(1).sort_values('VIF Factor', ascending=False).reset_index(drop=True)
vif
# Out:
#    VIF Factor                    features
# 0         5.2        FinTerms_ModalStrong
# 1         4.8           FinTerms_Positive
# 2         4.2  FinTerms_ModalStrong_count
# 3         3.8          FinTerms_Litigious
# 4         3.5    FinTerms_Litigious_count
# 5         3.3          FinTerms_ModalWeak
# 6         1.0    averageWordsPerParagraph

# %%
# isolate just text and 
cols = ['financialDistress_12_periods','date_month'] + list(text.columns[4:-1])
merged2 = merged[cols].dropna()

# split data into test, train
dropcols = [y_col, 'date_month']
X_train = merged2[merged2['date_month'] < '2010-1']
X_test = merged2[merged2['date_month'] >= '2010-1']
y_train = X_train[y_col]
y_test = X_test[y_col]
X_train, X_test = X_train.drop(columns=dropcols), X_test.drop(columns=dropcols)
print(X_train.shape, X_test.shape)
# Out:
# (628669, 26) (194421, 26)

# %% [markdown]
# ### Evaluate Models

# %%
# build model and fit on VIF features
cols = vif.features.tolist()
X = X_train[cols].copy()
scl = StandardScaler()
X = scl.fit_transform(X)
X = sm.add_constant(X)
log_reg = sm.Logit(y_train, X).fit()

# printing the summary table 
cols = ['constant'] + cols
print(log_reg.summary(xname=cols))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.153525
#          Iterations 8
#                                 Logit Regression Results
# ========================================================================================
# Dep. Variable:     financialDistress_12_periods   No. Observations:               628669
# Model:                                    Logit   Df Residuals:                   628661
# Method:                                     MLE   Df Model:                            7
# Date:                          Thu, 22 Apr 2021   Pseudo R-squ.:                0.007273
# Time:                                  13:16:23   Log-Likelihood:                -96516.
# converged:                                 True   LL-Null:                       -97224.
# Covariance Type:                      nonrobust   LLR p-value:                3.126e-301
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# constant                      -3.3277      0.007   -470.506      0.000      -3.342      -3.314
# FinTerms_ModalStrong           0.2237      0.014     16.280      0.000       0.197       0.251
# FinTerms_Positive             -0.4306      0.017    -25.739      0.000      -0.463      -0.398
# FinTerms_ModalStrong_count     0.0650      0.010      6.378      0.000       0.045       0.085
# FinTerms_Litigious            -0.0973      0.014     -6.951      0.000      -0.125      -0.070
# FinTerms_Litigious_count       0.0059      0.011      0.554      0.580      -0.015       0.027
# FinTerms_ModalWeak             0.0289      0.012      2.378      0.017       0.005       0.053
# averageWordsPerParagraph       0.0035      0.005      0.767      0.443      -0.005       0.012
# ==============================================================================================

# %%
# build model and fit on LASSO features
cols = lasso_train.columns.tolist()
X = X_train[cols].copy()
scl = StandardScaler()
X = scl.fit_transform(X)
X2 = scl.transform(X_test[cols])
X = sm.add_constant(X)
log_reg = sm.Logit(y_train, X).fit()

# printing the summary table 
cols = ['constant'] + cols
print(log_reg.summary(xname=cols))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.131760
#          Iterations 10
#                                 Logit Regression Results
# ========================================================================================
# Dep. Variable:     financialDistress_12_periods   No. Observations:               764180
# Model:                                    Logit   Df Residuals:                   764175
# Method:                                     MLE   Df Model:                            4
# Date:                          Wed, 21 Apr 2021   Pseudo R-squ.:                0.008633
# Time:                                  23:34:15   Log-Likelihood:            -1.0069e+05
# converged:                                 True   LL-Null:                   -1.0156e+05
# Covariance Type:                      nonrobust   LLR p-value:                     0.000
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# constant                      -3.5596      0.007   -477.246      0.000      -3.574      -3.545
# CharCount                    -12.6389      1.036    -12.196      0.000     -14.670     -10.608
# WordCount                     13.0889      0.739     17.711      0.000      11.640      14.537
# CharCountTokens                1.3254      0.759      1.747      0.081      -0.161       2.812
# LM_Master_Dictionary_count    -2.2020      0.358     -6.144      0.000      -2.905      -1.500
# ==============================================================================================

# %%
# build model and fit on Significant features
cols = o.index.tolist()
X = X_train[cols].copy()
scl = StandardScaler()
X = scl.fit_transform(X)
X2 = scl.transform(X_test[cols])
X = sm.add_constant(X)
log_reg = sm.Logit(y_train, X).fit()

# printing the summary table 
cols = ['constant'] + cols
print(log_reg.summary(xname=cols))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.153765
#          Iterations 8
#                                 Logit Regression Results
# ========================================================================================
# Dep. Variable:     financialDistress_12_periods   No. Observations:               628669
# Model:                                    Logit   Df Residuals:                   628665
# Method:                                     MLE   Df Model:                            3
# Date:                          Thu, 22 Apr 2021   Pseudo R-squ.:                0.005724
# Time:                                  14:59:16   Log-Likelihood:                -96667.
# converged:                                 True   LL-Null:                       -97224.
# Covariance Type:                      nonrobust   LLR p-value:                5.463e-241
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# constant                      -3.3171      0.007   -475.800      0.000      -3.331      -3.303
# FinTerms_Positive             -0.2495      0.011    -21.750      0.000      -0.272      -0.227
# FinTerms_Litigious            -0.0585      0.012     -4.985      0.000      -0.081      -0.035
# FinTerms_ModalStrong_count     0.1028      0.007     15.691      0.000       0.090       0.116
# ==============================================================================================

# %% [markdown]
# ### Single Stepwise Feature Selection

# %%
# split data into test, train
dropcols = [y_col,'date_month']
cols = ['NITA','NIMTA','TLTA','TLMTA','CASHMTA','EXRET','RSIZE','PRC','SIGMA','SIGMA_TLTA',
        'Gunning_Fog_Index','ARI','SMOG_Index','ParagraphCount','CharCount','WordCount',
        'ComplexWordCount','SentenceCount','averageWordsPerParagraph','CharCountTokens',
        'FinTerms_Negative','FinTerms_ModalWeak_count','FinTerms_ModalStrong_count', 
        'FinTerms_Positive','HarvardIV_Negative','FinTerms_Litigious_count','FinTerms_Uncertainty_count',
        'FinTerms_ModalWeak','FinTerms_Litigious','LM_Master_Dictionary','FinTerms_Uncertainty', 
        'LM_Master_Dictionary_count','HarvardIV_Negative_count','FinTerms_Negative_count',
        'FinTerms_ModalStrong','FinTerms_Positive_count'] + dropcols
merged2 = merged[cols].dropna()
X_train = merged2[merged2['date_month'] < '2010-1']
X_test = merged2[merged2['date_month'] >= '2010-1']
y_train = X_train[y_col]
y_test = X_test[y_col]
X_train, X_test = X_train.drop(columns=dropcols), X_test.drop(columns=dropcols)
print(X_train.shape, X_test.shape)
# Out:
# (628669, 36) (194421, 36)

# %%
# define individual test function
def test(cols):
    # scale data
    scl = StandardScaler()
    X = scl.fit_transform(X_train[cols])
    X2 = scl.transform(X_test[cols])

    # test logit model
    lgt = LogisticRegression(class_weight='balanced', random_state=10, max_iter=10000)
    lgt.fit(X, y_train)
    y_pred = lgt.predict(X2)
    y_prob = pd.DataFrame(lgt.predict_proba(X2))[0]
    
    # statsmodels for easy beta and r2
    log_reg = sm.Logit(y_train, X).fit()
    log_r2 = float(log_reg.summary2().tables[0][3][0])
    log_beta = float(log_reg.summary2().tables[1]['Coef.'][-1])
    log_z = float(log_reg.summary2().tables[1]['z'][-1])
    
    # statsmodels for easy beta and r2
    reg = OLS(y_train, X).fit()
    reg_r2 = float(reg.summary2().tables[0][3][0])
    reg_beta = float(reg.summary2().tables[1]['Coef.'][-1])
    reg_t = float(reg.summary2().tables[1]['t'][-1])

    # get performance
    acc = lgt.score(X2, y_test)
    cr = classification_report(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)
    prf = precision_recall_fscore_support(y_test, y_pred)
    output =  [reg_r2, reg_beta, reg_t, log_r2, log_beta, log_z, acc, auc, prf[0][1],
            prf[1][1], prf[2][1], prf[3][1], cr]
    return output

# define stepwise selection function
def stepwise(start_cols, test_cols):
    out = pd.DataFrame()
    if start_cols != []: out['none'] = test(start_cols)
    else: out['none'] = 0
    for col in test_cols:
        cols = start_cols + [col]
        out[col]  = test(cols)

    # final output processing
    out.index = ['reg_r2','reg_beta','reg_t','log_r2','log_beta','log_z','accuracy','auc',
                 'percision','recall','fscore','support','CR']
    out.loc[['reg_beta','reg_t','log_beta','log_z'],'none'] = 0
    return out.T

# %%
# test VIF features
add = [] # ['FinTerms_Litigious_count']
start_cols = ['NITA','TLTA','CASHMTA','EXRET','RSIZE','PRC','SIGMA','SIGMA_TLTA'] + add
test_cols = ['Gunning_Fog_Index','ARI','SMOG_Index','ParagraphCount','CharCount','WordCount',
        'ComplexWordCount','SentenceCount','averageWordsPerParagraph','CharCountTokens',
        'FinTerms_Negative','FinTerms_ModalWeak_count','FinTerms_ModalStrong_count', 
        'FinTerms_Positive','HarvardIV_Negative','FinTerms_Litigious_count','FinTerms_Uncertainty_count',
        'FinTerms_ModalWeak','FinTerms_Litigious','LM_Master_Dictionary','FinTerms_Uncertainty', 
        'LM_Master_Dictionary_count','HarvardIV_Negative_count','FinTerms_Negative_count',
        'FinTerms_ModalStrong','FinTerms_Positive_count']
test_cols = vif.features.tolist()
#[test_cols.remove(a) for a in add]
#out = stepwise(start_cols, test_cols[:])
cols = ['reg_r2','reg_beta','reg_t','log_beta','log_z']
o = out[cols].apply(abs).sort_values('reg_beta', ascending=False)
o = o[o.reg_t >= 2]
o
# Out:
#                            reg_r2    reg_beta    reg_t    log_beta     log_z
# FinTerms_Positive           0.113  0.00129108  5.61571  0.00558541   2.13159
# FinTerms_Litigious          0.113  0.00118197  5.17313  0.00358446   1.37507
# FinTerms_ModalStrong_count  0.113  0.00105666  4.66689  0.00140006  0.540576

# %%
merged[o.index].describe().T
# Out:
#                                count      mean        std  min  25%  50%  \
# FinTerms_Positive           823090.0  0.001838   0.003347  0.0  0.0  0.0
# FinTerms_Litigious          823090.0  0.002478   0.005468  0.0  0.0  0.0
# FinTerms_ModalStrong_count  823090.0  7.264345  24.165918  0.0  0.0  0.0
#
#                                  75%          max
# FinTerms_Positive           0.003222     0.030519
# FinTerms_Litigious          0.002786     0.079869
# FinTerms_ModalStrong_count  1.000000  1715.000000

# %%
# stepwise test as lone feature
#out_lone = stepwise([], test_cols[:])
cols = ['reg_r2','reg_beta','reg_t','log_beta','log_z']
ol = out_lone[cols].apply(abs).sort_values('log_beta', ascending=False)
ol = ol[ol.reg_t >= 2]
ol
# Out:
#                            reg_r2     reg_beta    reg_t    log_beta    log_z
# FinTerms_Positive           0.001   0.00669002  28.0176   0.0267674  10.6074
# FinTerms_Litigious          0.001   0.00479209   20.063   0.0191793    7.597
# FinTerms_ModalWeak              0   0.00392343  16.4245   0.0156999  6.22044
# FinTerms_ModalStrong            0   0.00307376  12.8665   0.0122964  4.87401
# FinTerms_Litigious_count        0    0.0010122  4.23649  0.00405328  1.60425
# FinTerms_ModalStrong_count      0  0.000768463  3.21632  0.00307434  1.21851

# %% [markdown]
# ### VIF for Full Features

# %%
# For each X, calculate VIF and save in dataframe
cols = ['NITA','NIMTA','TLTA','TLMTA','CASHMTA','EXRET','RSIZE','PRC','SIGMA','SIGMA_TLTA',
        'Gunning_Fog_Index','ARI','SMOG_Index','ParagraphCount','CharCount','WordCount',
        'ComplexWordCount','SentenceCount','averageWordsPerParagraph','CharCountTokens',
        'FinTerms_Negative','FinTerms_ModalWeak_count','FinTerms_ModalStrong_count', 
        'FinTerms_Positive','HarvardIV_Negative','FinTerms_Litigious_count','FinTerms_Uncertainty_count',
        'FinTerms_ModalWeak','FinTerms_Litigious','LM_Master_Dictionary','FinTerms_Uncertainty', 
        'LM_Master_Dictionary_count','HarvardIV_Negative_count','FinTerms_Negative_count',
        'FinTerms_ModalStrong','FinTerms_Positive_count']
vifcols = ['CharCountTokens','CharCount','WordCount','SMOG_Index','Gunning_Fog_Index',
           'LM_Master_Dictionary_count','ComplexWordCount','ARI','LM_Master_Dictionary',
           'HarvardIV_Negative_count','SentenceCount','FinTerms_Uncertainty_count',
           'HarvardIV_Negative','FinTerms_Negative_count','SentenceCount','FinTerms_Uncertainty', 
           'FinTerms_Positive_count','FinTerms_ModalWeak_count','NIMTA','TLMTA','RSIZE',
           'FinTerms_Negative','ParagraphCount','FinTerms_ModalStrong_count']
#cols = ['NITA','TLTA','CASHMTA','EXRET','PRC','SIGMA','SIGMA_TLTA'] # 'RSIZE'
X2 = merged[cols].dropna()
X2 = X2.drop(columns=vifcols)
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X2.values, i) for i in range(X2.shape[1])]
vif["features"] = X2.columns

# Inspect VIF scores
vifcols = list(vif.features)
vif = vif.round(1).sort_values('VIF Factor', ascending=False).reset_index(drop=True)
vif
# Out:
#     VIF Factor                  features
# 0          5.0         FinTerms_Positive
# 1          4.3      FinTerms_ModalStrong
# 2          3.5        FinTerms_Litigious
# 3          3.1        FinTerms_ModalWeak
# 4          2.9                      TLTA
# 5          2.6                SIGMA_TLTA
# 6          1.7                       PRC
# 7          1.6                     SIGMA
# 8          1.6  FinTerms_Litigious_count
# 9          1.4                   CASHMTA
# 10         1.2                      NITA
# 11         1.0                     EXRET
# 12         1.0  averageWordsPerParagraph

# %%
print(vif.features.tolist())
# Out:
# ['PRC', 'TLTA', 'FinTerms_Litigious', 'FinTerms_Positive', 'SIGMA_TLTA', 'FinTerms_ModalWeak_count', 'SIGMA', 'FinTerms_Litigious_count', 'FinTerms_Negative', 'FinTerms_ModalWeak', 'FinTerms_ModalStrong', 'CASHMTA', 'NITA', 'EXRET', 'averageWordsPerParagraph']

# %% [markdown]
# ### Raw SEC Data Merge

# %%
# load linking data
links = pd.read_csv('firm-links.csv')
links = links[['LPERMNO','cik','datadate']]
links['date_month'] = pd.to_datetime(links['datadate']).dt.to_period('M')
links = links.rename(columns={'LPERMNO':'PERMNO'})
links = links[['PERMNO','cik','date_month']]

# %%
# load firm data
data = pd.read_csv('data-clean.csv', low_memory=False)
#data = pd.read_csv('data-exclude.csv', low_memory=False)
data['PRC'] = np.where(data['PRC'] >= 15, 15, data['PRC'])
data['year'] = pd.to_datetime(data['date_month']).dt.to_period('Y')
data['date_month'] = pd.to_datetime(data['date_month']).dt.to_period('M')

# %%
# load text data
text = pd.read_csv('sec_report_links.csv', encoding='latin-1')
text['date_month'] = pd.to_datetime(text['secpdate'], format='%Y%m%d').dt.to_period('M')
text.form.value_counts()
# Out:
# 8-K     1790579
# 10-Q     719149
# 10-K     247967
# Name: form, dtype: int64

# %%
# merge process
print('Size pre-cik merge:', data[data['date_month'].between('1995-01','2018-12')].shape)
print('Date range:',data['date_month'].min(), data['date_month'].max(),'\n')

d = data[data['date_month'].between('1995-01','2018-12')]
merged = d.merge(links, on=['PERMNO','date_month'], how='left')
print('Size post-cik merge:', merged.shape)
print('Cik nan count:', merged.cik.isna().sum())
print('Date range:',merged['date_month'].min(), merged['date_month'].max(),'\n')

merged = merged.merge(text, on=['cik','date_month'], how='left')
print('Size post-text merge:', merged.shape)
print('Cik nan count:', merged.cik.isna().sum())
print('Date range:', merged['date_month'].min(), merged['date_month'].max(),'\n')
# Out:
# Size pre-cik merge: (1065641, 17)
# Date range: 1970-02 2018-12
#
# Size post-cik merge: (1065641, 18)
# Cik nan count: 634851
# Date range: 1995-01 2018-12
#
# Size post-text merge: (1237690, 25)
# Cik nan count: 634851
# Date range: 1995-01 2018-12

# %%
merged.to_csv('data-text-links.csv',index=False)

# %%
merged
# Out:
#         date_month  PERMNO       RET  RET-shifted        MKTCAP      NITA  \
# 0          1995-01   10001 -0.031250    -0.026210  1.723600e+04 -0.000220
# 1          1995-02   10001 -0.026210     0.006377  1.678426e+04  0.000469
# 2          1995-03   10001  0.006377     0.000000  1.683000e+04  0.000468
# 3          1995-04   10001  0.000000     0.050000  1.683000e+04  0.000468
# 4          1995-05   10001  0.050000     0.060317  1.767150e+04  0.000581
# ...            ...     ...       ...          ...           ...       ...
# 1237685    2018-07   93436 -0.130660     0.011806  5.086060e+07 -0.000139
# 1237686    2018-08   93436  0.011806    -0.122290  5.146108e+07 -0.000139
# 1237687    2018-09   93436 -0.122290     0.274011  4.542871e+07 -0.000157
# 1237688    2018-10   93436  0.274011     0.039013  5.792898e+07 -0.000123
# 1237689    2018-11   93436  0.039013    -0.050445  6.018898e+07  0.000052
#
#             NIMTA      TLTA     TLMTA   CASHMTA  ...  year  SIGMA_TLTA  \
# 0       -0.000022  0.012525  0.001273  0.000028  ...  1995    0.007149
# 1        0.000048  0.013574  0.001381  0.000035  ...  1995    0.008103
# 2        0.000048  0.013538  0.001378  0.000035  ...  1995    0.007774
# 3        0.000048  0.013538  0.001378  0.000035  ...  1995    0.007479
# 4        0.000059  0.011584  0.001177  0.000003  ...  1995    0.007466
# ...           ...       ...       ...       ...  ...   ...         ...
# 1237685 -0.000014  0.004215  0.000424  0.000055  ...  2018    0.002156
# 1237686 -0.000014  0.004377  0.000440  0.000046  ...  2018    0.002416
# 1237687 -0.000016  0.004954  0.000498  0.000052  ...  2018    0.003075
# 1237688 -0.000012  0.003890  0.000391  0.000041  ...  2018    0.002847
# 1237689  0.000005  0.003871  0.000389  0.000052  ...  2018    0.002821
#
#              cik       fdate  form                              wrdsfname  \
# 0        43350.0         NaN   NaN                                    NaN
# 1        43350.0         NaN   NaN                                    NaN
# 2        43350.0         NaN   NaN                                    NaN
# 3        43350.0         NaN   NaN                                    NaN
# 4        43350.0  19950515.0  10-Q  000004/43350/0000043350-95-000003.txt
# ...          ...         ...   ...                                    ...
# 1237685      NaN         NaN   NaN                                    NaN
# 1237686      NaN         NaN   NaN                                    NaN
# 1237687      NaN         NaN   NaN                                    NaN
# 1237688      NaN         NaN   NaN                                    NaN
# 1237689      NaN         NaN   NaN                                    NaN
#
#            fsize  doccount                                      fname  \
# 0            NaN       NaN                                        NaN
# 1            NaN       NaN                                        NaN
# 2            NaN       NaN                                        NaN
# 3            NaN       NaN                                        NaN
# 4        44265.0       2.0  edgar/data/43350/0000043350-95-000003.txt
# ...          ...       ...                                        ...
# 1237685      NaN       NaN                                        NaN
# 1237686      NaN       NaN                                        NaN
# 1237687      NaN       NaN                                        NaN
# 1237688      NaN       NaN                                        NaN
# 1237689      NaN       NaN                                        NaN
#
#            secpdate
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4        19950530.0
# ...             ...
# 1237685         NaN
# 1237686         NaN
# 1237687         NaN
# 1237688         NaN
# 1237689         NaN
#
# [1237690 rows x 25 columns]

# %%
# final processing
m = merged.groupby(['date_month','PERMNO']).mean()
m['doc_count'] = merged.groupby(['date_month','PERMNO']).count()['RET']
m['doc_count'] = np.where(m['FinTerms_Litigious'].isna(),0,m['doc_count'])
m = m.reset_index().drop(columns=['CIK','FDATE'])
m = m.replace(np.nan,0) # interaction variable btw presence & magnitude of report
print('Final size:', m.shape)
vc = m['financialDistress_12_periods'].value_counts(dropna=False)
print('Final distress count:', vc[1], '/', (vc[0]+vc[1]))
print('Final date range:', m['date_month'].min(), m['date_month'].max())
